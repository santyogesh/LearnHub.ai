# %% [markdown]
# # Task
# Fit the compound interest formula A = P(1+r)^t as an explicit exponential function to synthetic data using `scipy.optimize.curve_fit` and evaluate the results.

# %% [markdown]
# # Background
#
# Compound interest involves multiplying the principal by a set amount each year. This set amount depends on the rate. Such a process is inherently
# non-linear and are best modeled using a specific function form, such as an
# exponential function. Normal linear regression, wherein we seek to fit the function based on linear combinations in the "1st degree", cannot be done.

# %% [markdown]
# ## Generate synthetic data
#
# ### Subtask:
# We generated synthetic data for principal, time, and final amount based on the compound interest formula with a known interest rate, adding some noise to simulate real-world data. This data was used to train the model which performed the fitting.

# %% [markdown]
# **Reasoning**:
# The first step is to import the necessary libraries and set up the parameters for generating the synthetic data, including the true interest rate, principal amounts, and time periods.

# %% [markdown]
# Thereafter, we calculate the true final amounts based on the compound interest formula and then add noise to simulate real-world data.

# %% [markdown]
# ## Define the model function
#
# ### Subtask:
# then we defined the exponential function `A = P(1+r)^t` in a format suitable for `scipy.optimize`.

# %% [markdown]
# ## Fit the model
#
# ### Subtask:
# Use `scipy.optimize.curve_fit` to fit the defined exponential function to the generated data, estimating the interest rate `r`.

# %% [markdown]
# **Reasoning**:
# Import the necessary function and then use `curve_fit` to estimate the parameters of the compound interest function from the noisy data.

# %% [markdown]
# Graph of Amount vs Time (EDA)

# %% [markdown]
# Graph of Amount vs Principal vs Time

# %% [markdown]
# ## Evaluate the model
#
# ### Subtask:
# We shall evaluate the fitted model by comparing the predicted values with the actual values and potentially calculating metrics like R-squared or Mean Squared Error. R-squared and mean-squared are two popularly used error metrics to calculate the accuracy of fit of data. The lower the MSE, the better, whereas R-square takes values from 0-1 with 1 being a perfect fit.

# %% [markdown]
# **Reasoning**:
# Calculate the predicted amounts using the fitted parameter, then calculate the Mean Squared Error and R-squared value to evaluate the model's performance.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Synthetic data for compound interest with added noise was successfully generated for principal amounts from \$1000 to \$5000 and time periods from 1 to 3 years.
# *   The compound interest formula `A = P(1+r)^t` was defined as a Python function suitable for curve fitting.
# *   `scipy.optimize.curve_fit` was successfully used to fit the redefined compound interest function to the noisy synthetic data.
# *   The fitting process estimated the interest rate `r`. While the exact estimated rate is not provided in the output, the process was successful.
# *   The Mean Squared Error (MSE) between the noisy actual amounts and the predicted amounts from the fitted model is approximately 240498.
# *   The R-squared (R2) value, indicating the proportion of the variance in the dependent variable that is predictable from the independent variables, is approximately 0.9966.
# *   A plot visualizing the original noisy data and the fitted curve for a principal of \3000 shows that the fitted exponential curve closely follows the trend of the data points.
#
# ### Insights or Next Steps
#
# *   The high R-squared value (0.9966) and the visual inspection of the plot suggest that the compound interest model is a very good fit for the generated synthetic data, even with the added noise.
# *   To further evaluate the model, it would be beneficial to compare the estimated interest rate `r` from the curve fitting process to the true interest rate (`r_true = 0.05`) used to generate the synthetic data.

# %% [markdown]
# #Fintech Applications:
#  There are a lot of applications of models like this in the fintech domain, some of which are listed below:
#
# **Loan Analysis** → The technique aligns the repayment sizes with the compound interest curve, which is used to estimate the actual annual interest charge. This indicates the actual cost of borrowing where lenders give misleading flat or monthly rates.
#
# **Investment Platforms** → By training the model with past returns, robo-advisors can estimate portfolio growth. For example, given deposits and time horizons, the model calculates the end value and then back-calculates the implied growth rate.
#
# **Savings & Micro-investment Apps** → The model employs time and small deposits as predictors of the amount saved. This is used to enable apps to display users how much their savings would amount to and encourage more saving.
#
# **Credit Risk Assessment** → Whenever payments are not as expected, the system identifies probable risks. It assists lenders in identifying defaults beforehand by comparing predicted and realized payment amounts.
#
# **Multi-currency & Cross-border Finance** → The same growth model, when replicated, can be applied with account balances in various currencies. It approximates interest rates equally well for INR, USD, EUR, or even crypto trading.
#
# Regulators can utilize this model to analyze fintech information and determine whether interest rates provided by advertisements are the same as rates determined by mathematics. This makes it transparent and guards customers.
