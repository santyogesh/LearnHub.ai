# %% [markdown]
# # Overview
#
# In the field of AI/ML, data should be structured in a clear and concise manner so that it may be used to train AI models. This is very important in all fields but especially important in the FinTech industry because of its complex and varied data in the form of customer feedbacks. This dataset represents customer reviews in multiple languages.
#
# # Methodology
#
# To properly structure a dataset, we need to break it down into input features and the corresponding output values. The entire dataset is denoted by *D*. We have defined the dataset's core components:
#
#
#
# *   The total number of examples (m)
# *   The input variables used for prediction (x)
# *   The target variables predicted (y)
#
# Using this notation, the dataset *D* can be expressed as:
#
# $$D = \{<x_{1},y_{1}>,<x_{2},y_{2}>,....,<x_{m},y_{m}>\}$$
#
# This structure can be applied to practically any dataset.
#
# # Multilingual Data Handling
#
# The dataset we have used consists of data in multiple languages. This is a common problem in Natural Language Processing (NLP). For a model to understand the text in these datasets, special techniques are required or we can just translate all the text into a single language.
#
# However, regardless of the language does not change the fundamental structure of the dataset, nor does it change the notation. Hence, the "Review" column is treated as normal input feature.
#
# Now, Data Notation is crucial to various multilingual machine learning models. These area achieved through various annotation techniques such as:
#
# *   Named Entity Recognition (NER): This involves identifying and categorizing various key information in the text like such as names of people, organisations, locations etc.
#
# *   Sentiment Analysis: Annotating text with various sentiment labels allows model to gauge the opinions and emotions expressed in different languages.
#
# *   Text Application: This can be used to categorize different reviews according to the language and gauge reactions according to the culture, tailoring the experience for that particular region or language.
#
# Some methods of detecting languages include:
#
# *   Encoding: We should store and process text in **UTF-8**. This can handle most of the world's languages.
#
# *   Language Detection: If the data doesn't already come with labels for languages then we can use tools like **langdetect**,**fastText** or **langid** to segregrate the languages.
#
# *   Tokenization: We can see what differentiates the languages like Hindi, English, Spanish etc use spaces in the language while Japanese, Chinese etc don't use them. We can also use language-specific tokenizers like spaCy, IndicNLP etc.
#
# *   Normalization and Cleaning: We have to remove standard punctuations, special characters, emojis etc. We can also handle stopwords (words that repeat very often in languages) for multiple languages.
#
# # FinTech Applications
#
# Talking about FinTech applications, this is probably the most used method for dataset notation.
#
# The dataset that we have chosen can used to analyze customer feedback to predict user satisfaction and engagement.
#
# A FinTech company could use this data train a regression model to find a relationship between user's age and review text. This could then allow the company to identify problems and improve its customer service.
#
# The other FinTech applications include:
#
# *   Fraud Detection: By labeling certain transaction data as "fraud" or "scam", then the models will become better at detecting fraudulent activity.
#
# *   Personalised Customer Experience: By annotating customer experiences, support tickets, and feedback with labels (positive, negative and neutral) or intent (account inquiry, transaction dispute), companies can build models that provide personalized experience for customers throught chatbots.
#
# *   Churn Prediction: Predict which users are likely to disengage based on reviews and ratings.
#
# *   Localized Product Insights: Compare feedback across languages/countries to tailor financial services.
#
# #Citations
#
# *   https://learningspiral.ai/data-annotation-for-financial-services-driving-intelligent-decision-making/#:~:text=Personalized%20Customer%20Service%3A%20Sentiment%20analysis,Difficulties%20in%20the%20Path
#
# *   https://macgence.com/blog/banking-data-annotation-solutions/
#
# *   https://activeloc.com/blog/language-data-annotation-in-multilingual-ai/
#
# *   https://medium.com/@thakrandisharth/tackling-global-data-challenges-with-multilingual-data-processing-feb2620d3000
#
# *   https://sigma.ai/what-is-data-annotation/#:~:text=Through%20sentiment%20annotation%2C%20the%20model,based%20on%20their%20subject%20matter.
#
# # Implementation
#
# The code calculates the total training examples (m) by counting the number of instances of data.
#
# we have chosen "review_text" and "user_age" columns as input variables while "num_helpful_votes" and "rating" are the target variables. The given dataset can be used by the company to analyse its products/services based on the "review_text" and "user_age". This will help them to understand the reviews among different age groups. "rating" and "num_helpful_votes" for a particular review will help the company to understand how many people support the review and accordingly they can take actions on improving quality etc.
#
# Then, the code scans each row to print the entire dataset in the notation described before.
#
# Some of the text in "review_text" is a garbled mess because they are in languages whose font could not be loaded.

# %%
#Load suitable libraries
import pandas as pd
import numpy as np

import kagglehub
from kagglehub import KaggleDatasetAdapter

file_path = "multilingual_mobile_app_reviews_2025.csv"

print(f"Loading '{file_path}' from Kaggle Hub...")

df = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "pratyushpuri/multilingual-mobile-app-reviews-dataset-2025",
    file_path,
)

print("Dataset loaded successfully.")


#No. of training examples
m = df.shape[0]

#X is a vector consisting of 2 input features
X = df[['review_text','user_age']]

#Y is a vector consisting of 2 output features
Y = df[['num_helpful_votes','rating']]

#Print the no. of training examples
print("\nNo. of training examples : ",m)

#Print the input features
print("\nX:")
print(X)

#Print the target features
print("\nY:")
print(Y)

#Print the dataset D in the format D=< x1, y1 >, .., < xm, ym>
i=0
print("\nDataset (D) =")
while i<m:
  # Using .iloc[i].values.tolist() is slightly more robust
  print("<", tuple(X.iloc[i].values.tolist()), ",", tuple(Y.iloc[i].values.tolist()), ">")
  i+=1
# Out:
# Loading 'multilingual_mobile_app_reviews_2025.csv' from Kaggle Hub...
# /tmp/ipython-input-978745115.py:12: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
# Dataset loaded successfully.
#
# No. of training examples :  2514
#
# X:
#                                             review_text  user_age
# 0     Qui doloribus consequuntur. Perspiciatis tempo...      14.0
# 1     Great app but too many ads, consider premium v...      18.0
# 2     The interface could be better but overall good...      67.0
# 3     Latest update broke some features, please fix ...      66.0
# 4     Perfect for daily use, highly recommend to eve...      40.0
# ...                                                 ...       ...
# 2509  Счастье низкий пастух. Нож неожиданно поезд тр...      21.0
# 2510  This app is amazing! Really love the new featu...      38.0
# 2511  This app is amazing! Really love the new featu...      27.0
# 2512  Invitare convincere pericoloso corsa fortuna. ...      35.0
# 2513  Latest update broke some features, please fix ...      26.0
#
# [2514 rows x 2 columns]
#
# Y:
#       num_helpful_votes  rating
# 0                    65     1.3
# 1                   209     1.6
# 2                   163     3.6
# 3                   664     3.8
# 4                  1197     3.2
# ...                 ...     ...
# 2509                635     3.0
# 2510               1127     1.9
# 2511                677     3.4
# 2512                155     2.7
# 2513               1040     2.1
#
# [2514 rows x 2 columns]
#
# Dataset (D) =
# < ('Qui doloribus consequuntur. Perspiciatis tempora assumenda in. Atque doloremque nobis.', np.float64(14.0)) , (65.0, 1.3) >
# < ('Great app but too many ads, consider premium version.', np.float64(18.0)) , (209.0, 1.6) >
# < ('The interface could be better but overall good experience.', np.float64(67.0)) , (163.0, 3.6) >
# < ('Latest update broke some features, please fix soon.', np.float64(66.0)) , (664.0, 3.8) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(40.0)) , (1197.0, 3.2) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(75.0)) , (514.0, 5.0) >
# < ('Basso bello società paese. Quello mostrare verso.', np.float64(68.0)) , (217.0, 4.0) >
# < ('Odcinek skład zarówno zgodnie zaś. Powoli gdyby gleba.', np.float64(18.0)) , (161.0, 1.2) >
# < ('Eius odio facilis fuga distinctio eaque. Non cupiditate quas cum. Earum unde porro dolor eveniet quisquam.', np.float64(55.0)) , (817.0, 1.8) >
# < ('Husband at tree note responsibility defense.', np.float64(45.0)) , (145.0, 4.6) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(56.0)) , (110.0, 2.7) >
# < ('The interface could be better but overall good experience.', np.float64(16.0)) , (200.0, 4.2) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(40.0)) , (584.0, 4.7) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(67.0)) , (164.0, 1.2) >
# < ('Latest update broke some features, please fix soon.', np.float64(29.0)) , (488.0, 3.7) >
# < ('Great app but too many ads, consider premium version.', np.float64(23.0)) , (583.0, 4.5) >
# < ('Sorprendere circa collo. Organizzare giudizio organizzare libro diretto nemmeno. Prendere calcio stasera.', np.float64(58.0)) , (431.0, 2.1) >
# < ('Crashes too often, needs improvement in stability.', np.float64(48.0)) , (904.0, 4.9) >
# < ('Great app but too many ads, consider premium version.', np.float64(55.0)) , (511.0, 4.6) >
# < ('Voluptas quis magni autem numquam. Non corrupti quis molestiae quod minus a.', np.float64(23.0)) , (546.0, 4.5) >
# < ('Latest update broke some features, please fix soon.', np.float64(54.0)) , (719.0, 4.9) >
# < ('Great app but too many ads, consider premium version.', np.float64(37.0)) , (236.0, 3.4) >
# < ('The interface could be better but overall good experience.', np.float64(55.0)) , (633.0, 4.6) >
# < ('Excellent customer support and regular feature updates.', np.float64(41.0)) , (904.0, 3.6) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(75.0)) , (501.0, 1.6) >
# < ('Das lachen mich Freude.', np.float64(28.0)) , (1141.0, 3.1) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(53.0)) , (992.0, 2.1) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(26.0)) , (127.0, 3.2) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(30.0)) , (449.0, 4.6) >
# < ('This app is amazing! Really love the new features.', np.float64(24.0)) , (945.0, 3.6) >
# < ('Great app but too many ads, consider premium version.', np.float64(73.0)) , (63.0, 3.6) >
# < ('The interface could be better but overall good experience.', np.float64(14.0)) , (1185.0, 4.9) >
# < (nan, np.float64(45.0)) , (141.0, 3.1) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(33.0)) , (549.0, 2.9) >
# < ('Latest update broke some features, please fix soon.', np.float64(48.0)) , (565.0, 2.1) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(48.0)) , (969.0, 3.7) >
# < ('Scoprire considerare bello insomma infine libertà quasi.', np.float64(59.0)) , (566.0, 1.9) >
# < ('Покидать деловой хлеб низкий. Чем передо пробовать заработать костер.', np.float64(68.0)) , (210.0, 4.8) >
# < ('This app is amazing! Really love the new features.', np.float64(18.0)) , (622.0, 1.6) >
# < ('Excellent customer support and regular feature updates.', np.float64(53.0)) , (425.0, 3.4) >
# < ('創傷ホイールバス状況極端な。', np.float64(55.0)) , (1207.0, 1.9) >
# < ('User-friendly design and smooth performance throughout.', np.float64(45.0)) , (557.0, 2.2) >
# < ('Crashes too often, needs improvement in stability.', np.float64(24.0)) , (569.0, 3.1) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(29.0)) , (644.0, 1.1) >
# < ('User-friendly design and smooth performance throughout.', np.float64(30.0)) , (416.0, 2.8) >
# < ('The interface could be better but overall good experience.', np.float64(73.0)) , (945.0, 5.0) >
# < ('Рот человечек мелькнуть единый набор вариант выраженный. Господь дошлый парень бабочка дьявол проход плясать. Выразить миф господь разводить прежний.', np.float64(34.0)) , (849.0, 4.5) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(75.0)) , (386.0, 2.8) >
# < ('Excellent customer support and regular feature updates.', np.float64(46.0)) , (204.0, 4.5) >
# < ('Srebro obiekt zdrowie wywołać. Co gniew Polak pięć. Pracownik dziedzina okręt chyba bogini gazeta silny.', np.float64(15.0)) , (1108.0, 4.8) >
# < ('This app is amazing! Really love the new features.', np.float64(28.0)) , (298.0, 2.4) >
# < ('User-friendly design and smooth performance throughout.', np.float64(56.0)) , (589.0, 3.7) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(14.0)) , (604.0, 2.4) >
# < ('Freude warum sie die. Nichts schön erklären Onkel fressen. Flasche weit baden Onkel turnen Auge Glas.', np.float64(70.0)) , (198.0, 3.5) >
# < ('Qui mollitia incidunt ab. Velit porro corrupti alias. Nesciunt corporis consectetur est tempore recusandae.', np.float64(71.0)) , (526.0, 4.7) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(37.0)) , (1197.0, 2.8) >
# < ('The interface could be better but overall good experience.', np.float64(44.0)) , (623.0, 1.2) >
# < ('Latest update broke some features, please fix soon.', np.float64(41.0)) , (908.0, 3.8) >
# < ('Excellent customer support and regular feature updates.', np.float64(21.0)) , (498.0, 1.2) >
# < ('Потом ремень конструкция слишком заплакать. Ложиться обида карандаш правление низкий идея.', np.float64(13.0)) , (269.0, 1.4) >
# < ('User-friendly design and smooth performance throughout.', np.float64(59.0)) , (88.0, 1.9) >
# < ('The interface could be better but overall good experience.', np.float64(58.0)) , (1123.0, 2.1) >
# < ('User-friendly design and smooth performance throughout.', np.float64(40.0)) , (640.0, 2.7) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(35.0)) , (841.0, 2.3) >
# < ('Eveniet sint vitae eius odit id. Ex adipisci soluta ea neque voluptates alias. Ipsa quas et non maiores harum nemo ducimus.', np.float64(27.0)) , (1175.0, 1.5) >
# < ('Crashes too often, needs improvement in stability.', np.float64(22.0)) , (142.0, 3.3) >
# < ('Excellent customer support and regular feature updates.', np.float64(55.0)) , (907.0, 3.7) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(73.0)) , (617.0, 1.2) >
# < ('This app is amazing! Really love the new features.', np.float64(49.0)) , (641.0, 1.1) >
# < ('Excellent customer support and regular feature updates.', np.float64(60.0)) , (635.0, 3.1) >
# < ('Crashes too often, needs improvement in stability.', np.float64(73.0)) , (362.0, 1.6) >
# < ('Latest update broke some features, please fix soon.', np.float64(17.0)) , (1039.0, 3.4) >
# < ('Excellent customer support and regular feature updates.', np.float64(45.0)) , (974.0, 1.8) >
# < ('Great app but too many ads, consider premium version.', np.float64(62.0)) , (837.0, 4.7) >
# < ('Crashes too often, needs improvement in stability.', np.float64(51.0)) , (264.0, 2.2) >
# < ('Crashes too often, needs improvement in stability.', np.float64(27.0)) , (393.0, 2.4) >
# < ('Crashes too often, needs improvement in stability.', np.float64(59.0)) , (339.0, 4.3) >
# < ('Excellent customer support and regular feature updates.', np.float64(45.0)) , (782.0, 2.8) >
# < ('Crashes too often, needs improvement in stability.', np.float64(66.0)) , (301.0, 2.8) >
# < ('This app is amazing! Really love the new features.', np.float64(21.0)) , (299.0, 4.7) >
# < ('Порог тревога правление промолчать около пламя разуметься. Направо дыхание означать горький. Табак пастух а засунуть встать.', np.float64(28.0)) , (590.0, 3.1) >
# < ('This app is amazing! Really love the new features.', np.float64(24.0)) , (853.0, 2.4) >
# < ('看到发布表示完成完全浏览继续. 所以原因查看他们一些. 开发能够登录一定.', np.float64(28.0)) , (706.0, 2.4) >
# < ('User-friendly design and smooth performance throughout.', np.float64(69.0)) , (408.0, 2.2) >
# < ('Great app but too many ads, consider premium version.', np.float64(34.0)) , (791.0, 4.6) >
# < ('The interface could be better but overall good experience.', np.float64(51.0)) , (913.0, 3.6) >
# < ('Crashes too often, needs improvement in stability.', np.float64(15.0)) , (897.0, 1.6) >
# < ('Great app but too many ads, consider premium version.', np.float64(74.0)) , (511.0, 2.3) >
# < ('The interface could be better but overall good experience.', np.float64(64.0)) , (179.0, 1.7) >
# < ('Occaecati earum aspernatur enim earum eum molestiae.', np.float64(48.0)) , (739.0, 4.2) >
# < ('Great app but too many ads, consider premium version.', np.float64(35.0)) , (1059.0, 1.3) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(67.0)) , (581.0, 4.8) >
# < ('Excellent customer support and regular feature updates.', np.float64(15.0)) , (1154.0, 4.6) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(41.0)) , (323.0, 2.8) >
# < ('User-friendly design and smooth performance throughout.', np.float64(19.0)) , (288.0, 2.1) >
# < ('Latest update broke some features, please fix soon.', np.float64(42.0)) , (1035.0, 1.1) >
# < ('Sonno rimanere giovane. Tu esame giù.', np.float64(49.0)) , (104.0, 2.5) >
# < ('Great app but too many ads, consider premium version.', np.float64(45.0)) , (822.0, 1.8) >
# < ('Stupido malattia donna magari già posare sbagliare qualità. Tempo vino morale sviluppo ora popolazione avvicinare.', np.float64(44.0)) , (1090.0, 2.3) >
# < ('Amet fugiat distinctio eveniet. Eius veritatis in rerum iusto quibusdam. Voluptatum expedita officiis.', np.float64(43.0)) , (1195.0, 1.9) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(68.0)) , (965.0, 3.0) >
# < ('Latest update broke some features, please fix soon.', np.float64(48.0)) , (571.0, 2.9) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(74.0)) , (706.0, 4.6) >
# < ('Excellent customer support and regular feature updates.', np.float64(55.0)) , (103.0, 3.3) >
# < ('Latest update broke some features, please fix soon.', np.float64(54.0)) , (183.0, 2.1) >
# < ('Cold parent security boy standard who. Official up office traditional.', np.float64(42.0)) , (582.0, 3.4) >
# < ('Great app but too many ads, consider premium version.', np.float64(52.0)) , (359.0, 3.3) >
# < ('Latest update broke some features, please fix soon.', np.float64(29.0)) , (23.0, 2.2) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(36.0)) , (1240.0, 2.9) >
# < ('Quos expedita incidunt fuga magni exercitationem sed.', np.float64(47.0)) , (1172.0, 4.6) >
# < ('Excellent customer support and regular feature updates.', np.float64(38.0)) , (44.0, 3.2) >
# < ('Crashes too often, needs improvement in stability.', np.float64(70.0)) , (766.0, 4.9) >
# < ('Crashes too often, needs improvement in stability.', np.float64(75.0)) , (46.0, 4.9) >
# < ('Nulla ullam quo iure repudiandae. Eaque sequi rerum assumenda sunt doloribus iure nostrum. Excepturi laudantium eveniet laborum explicabo ea.', np.float64(51.0)) , (206.0, 2.0) >
# < ('Excellent customer support and regular feature updates.', np.float64(32.0)) , (485.0, 3.3) >
# < ('Assumenda quam laborum quidem porro. Ipsum accusantium eos illo doloribus optio fuga. Minus incidunt quia ex praesentium earum dolorum.', np.float64(24.0)) , (770.0, 2.6) >
# < ('Latest update broke some features, please fix soon.', np.float64(67.0)) , (921.0, 2.3) >
# < ('Great app but too many ads, consider premium version.', np.float64(72.0)) , (433.0, 4.8) >
# < ('Great app but too many ads, consider premium version.', np.float64(42.0)) , (1018.0, 2.0) >
# < ('大小正在不要图片提供.', np.float64(66.0)) , (1166.0, 2.3) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(66.0)) , (69.0, 4.8) >
# < (nan, np.float64(47.0)) , (13.0, 3.6) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(18.0)) , (812.0, 4.3) >
# < ('This app is amazing! Really love the new features.', np.float64(54.0)) , (888.0, 1.7) >
# < ('This app is amazing! Really love the new features.', np.float64(74.0)) , (32.0, 4.7) >
# < ('Crashes too often, needs improvement in stability.', np.float64(16.0)) , (708.0, 3.9) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(18.0)) , (778.0, 1.7) >
# < ('Latest update broke some features, please fix soon.', np.float64(21.0)) , (209.0, 2.4) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(49.0)) , (497.0, 3.9) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(42.0)) , (400.0, 3.5) >
# < ('Excellent customer support and regular feature updates.', np.float64(74.0)) , (363.0, 1.8) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(73.0)) , (55.0, 3.7) >
# < ('Corrupti natus esse voluptatibus. Nam impedit nisi nulla.', np.float64(50.0)) , (981.0, 2.8) >
# < (nan, np.float64(74.0)) , (679.0, 3.3) >
# < ('Crashes too often, needs improvement in stability.', np.float64(31.0)) , (214.0, 5.0) >
# < ('狭い数字私スキーム品質。 バスクロス教授フレーム主人コミュニティピック溝。', np.float64(67.0)) , (46.0, 2.2) >
# < ('Crashes too often, needs improvement in stability.', np.float64(60.0)) , (59.0, 3.6) >
# < ('The interface could be better but overall good experience.', np.float64(74.0)) , (1080.0, 3.7) >
# < ('Great app but too many ads, consider premium version.', np.float64(36.0)) , (374.0, 2.0) >
# < ('Crashes too often, needs improvement in stability.', np.float64(68.0)) , (109.0, 4.4) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(31.0)) , (1101.0, 1.1) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(68.0)) , (609.0, 3.9) >
# < ('Crashes too often, needs improvement in stability.', np.float64(64.0)) , (423.0, 1.6) >
# < ('Architecto cumque esse quibusdam. Ullam ipsa iusto esse illo earum molestiae.', np.float64(28.0)) , (271.0, 5.0) >
# < ('Latest update broke some features, please fix soon.', np.float64(73.0)) , (931.0, 4.7) >
# < ('Historyczny szkoła rzucić łyżka akt szkodliwy Piotr dolina.', np.float64(48.0)) , (691.0, 2.1) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(23.0)) , (618.0, 5.0) >
# < (nan, np.float64(56.0)) , (1063.0, 1.5) >
# < (nan, np.float64(17.0)) , (292.0, 2.5) >
# < ('The interface could be better but overall good experience.', np.float64(33.0)) , (879.0, 3.9) >
# < ('广告如何最新我的. 人员留言功能次数. 产品现在主要发表得到很多其实.', np.float64(37.0)) , (1013.0, 4.1) >
# < ('User-friendly design and smooth performance throughout.', np.float64(29.0)) , (28.0, 1.1) >
# < ('Latest update broke some features, please fix soon.', np.float64(75.0)) , (416.0, 2.2) >
# < ('Quidem numquam quis dignissimos molestias unde ipsa praesentium. Adipisci occaecati reiciendis quae.', np.float64(20.0)) , (359.0, 3.4) >
# < ('Impact different success box water positive child. Meeting event strong woman during.', np.float64(58.0)) , (538.0, 2.1) >
# < ('Two meet these tell everybody.', np.float64(37.0)) , (745.0, 2.0) >
# < ('Eaque a quas saepe neque optio sint. Molestiae exercitationem mollitia molestiae iste eum deleniti.', np.float64(27.0)) , (367.0, 3.0) >
# < ('Latest update broke some features, please fix soon.', np.float64(50.0)) , (754.0, 3.5) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(46.0)) , (420.0, 3.9) >
# < ('Crashes too often, needs improvement in stability.', np.float64(49.0)) , (1212.0, 4.3) >
# < ('Lendemain annoncer lien nombre. Songer haute maître immense. Fuir père choisir intéresser.', np.float64(42.0)) , (920.0, 1.6) >
# < ('Great app but too many ads, consider premium version.', np.float64(38.0)) , (728.0, 1.4) >
# < ('Crashes too often, needs improvement in stability.', np.float64(25.0)) , (267.0, 1.0) >
# < ('Great app but too many ads, consider premium version.', np.float64(23.0)) , (103.0, 1.2) >
# < ('Excellent customer support and regular feature updates.', np.float64(69.0)) , (843.0, 3.6) >
# < ('User-friendly design and smooth performance throughout.', np.float64(37.0)) , (658.0, 4.7) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(49.0)) , (449.0, 3.1) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(15.0)) , (1004.0, 3.2) >
# < ('Crashes too often, needs improvement in stability.', np.float64(36.0)) , (148.0, 4.4) >
# < ('Draußen Geburtstag Angst gestern bauen halten. Denn Mama Mutter Stein drei Bett. Ob Feuer weiß denken kochen fliegen.', np.float64(59.0)) , (628.0, 4.3) >
# < ('User-friendly design and smooth performance throughout.', np.float64(35.0)) , (487.0, 2.3) >
# < ('The interface could be better but overall good experience.', np.float64(59.0)) , (897.0, 1.0) >
# < ('Latest update broke some features, please fix soon.', np.float64(23.0)) , (768.0, 1.3) >
# < ('Great app but too many ads, consider premium version.', np.float64(59.0)) , (1134.0, 4.9) >
# < ('Excellent customer support and regular feature updates.', np.float64(23.0)) , (423.0, 1.8) >
# < ('Dicta harum laboriosam dolores nemo.', np.float64(29.0)) , (952.0, 1.2) >
# < ('Dar mieć na imię kawałek. Św. ciężar trwały opuścić Austria wysłać dokładny. Umiejętność grzyb uderzać gniew sport.', np.float64(69.0)) , (1172.0, 4.9) >
# < ('Blanc pareil apparence réserver anglais façon certes tellement.', np.float64(65.0)) , (413.0, 1.3) >
# < ('This app is amazing! Really love the new features.', np.float64(20.0)) , (859.0, 3.5) >
# < ('User-friendly design and smooth performance throughout.', np.float64(30.0)) , (352.0, 3.4) >
# < ('Latest update broke some features, please fix soon.', np.float64(75.0)) , (201.0, 2.1) >
# < ('Trzymać szklanka 50 wynosić. Cierpienie cierpieć raz prawny jednak temu.', np.float64(32.0)) , (134.0, 3.1) >
# < ('作者电子文件时候而且您的. 搜索控制计划文章设计.', np.float64(28.0)) , (62.0, 3.0) >
# < ('Excellent customer support and regular feature updates.', np.float64(30.0)) , (423.0, 4.4) >
# < ('科技非常处理解决. 还是次数会员应该. 同时投资朋友介绍.', np.float64(67.0)) , (771.0, 3.6) >
# < ('The interface could be better but overall good experience.', np.float64(68.0)) , (665.0, 1.3) >
# < ('Omnis rerum nulla vel eius porro. Ipsam veritatis sequi aut placeat.', np.float64(37.0)) , (828.0, 2.0) >
# < ('Потрясти упорно вчера торговля.', np.float64(59.0)) , (529.0, 1.4) >
# < ('The interface could be better but overall good experience.', np.float64(73.0)) , (1188.0, 1.2) >
# < ('Excellent customer support and regular feature updates.', np.float64(44.0)) , (165.0, 1.6) >
# < ('User-friendly design and smooth performance throughout.', np.float64(59.0)) , (408.0, 1.0) >
# < ('Excellent customer support and regular feature updates.', np.float64(73.0)) , (610.0, 1.7) >
# < ('Crashes too often, needs improvement in stability.', np.float64(23.0)) , (1033.0, 3.9) >
# < ('The interface could be better but overall good experience.', np.float64(29.0)) , (1120.0, 2.8) >
# < ('Ratione nisi eius voluptates. Molestiae reiciendis beatae sint. Accusamus ratione dolores eum.', np.float64(63.0)) , (233.0, 3.5) >
# < ('User-friendly design and smooth performance throughout.', np.float64(71.0)) , (182.0, 1.9) >
# < ('The interface could be better but overall good experience.', np.float64(64.0)) , (737.0, 4.5) >
# < ('Great app but too many ads, consider premium version.', np.float64(30.0)) , (934.0, 1.5) >
# < ('Crashes too often, needs improvement in stability.', np.float64(68.0)) , (59.0, 2.5) >
# < ('Great app but too many ads, consider premium version.', np.float64(40.0)) , (195.0, 3.1) >
# < ('Aliquam quos sint maxime itaque vitae aperiam laboriosam. Incidunt autem quae ipsam tempore eum.', np.float64(45.0)) , (103.0, 2.0) >
# < ('Peggio onore provocare giovane origine. Lato pagina bestia profondo solito. Qualche creare largo decisione fine lato impressione.', np.float64(48.0)) , (73.0, 1.4) >
# < ('Wyrażenie warunek posiadać sukienka głowa wracać. Zimny chłop fala wartość.', np.float64(43.0)) , (1228.0, 3.2) >
# < ('再現する同行コンペ敵対的な販売敵改善。', np.float64(29.0)) , (219.0, 4.0) >
# < ('暖かい出演者拡張ホイールバナーシェービング。 ニュース品質埋め込むサワーバナー彼女高い。', np.float64(74.0)) , (275.0, 3.4) >
# < ('Excellent customer support and regular feature updates.', np.float64(39.0)) , (787.0, 4.5) >
# < ('Excellent customer support and regular feature updates.', np.float64(75.0)) , (271.0, 2.2) >
# < ('This app is amazing! Really love the new features.', np.float64(30.0)) , (409.0, 1.6) >
# < ('Расстегнуть поздравлять мгновение разводить коммунизм уронить. Пространство вариант бегать.', np.float64(72.0)) , (96.0, 3.0) >
# < ('Excellent customer support and regular feature updates.', np.float64(41.0)) , (602.0, 4.1) >
# < ('Crashes too often, needs improvement in stability.', np.float64(16.0)) , (1222.0, 1.6) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(69.0)) , (453.0, 2.6) >
# < ('So baden Bild kann.', np.float64(37.0)) , (232.0, 4.5) >
# < ('The interface could be better but overall good experience.', np.float64(13.0)) , (1092.0, 4.9) >
# < ('Great app but too many ads, consider premium version.', np.float64(63.0)) , (364.0, 1.4) >
# < ('Excellent customer support and regular feature updates.', np.float64(57.0)) , (93.0, 4.0) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(56.0)) , (610.0, nan) >
# < ('Portare anzi grazia osservare accettare esercito costituire. Rifiutare elemento cane marito.', np.float64(23.0)) , (291.0, 2.7) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(21.0)) , (731.0, 3.3) >
# < ('Great app but too many ads, consider premium version.', np.float64(63.0)) , (504.0, 1.7) >
# < ('Excellent customer support and regular feature updates.', np.float64(25.0)) , (1103.0, 4.4) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(38.0)) , (749.0, 3.6) >
# < ('Crashes too often, needs improvement in stability.', np.float64(60.0)) , (299.0, 3.3) >
# < ('User-friendly design and smooth performance throughout.', np.float64(58.0)) , (211.0, 1.2) >
# < ('Great app but too many ads, consider premium version.', np.float64(45.0)) , (13.0, 4.2) >
# < ('User-friendly design and smooth performance throughout.', np.float64(14.0)) , (841.0, 1.8) >
# < ('Excellent customer support and regular feature updates.', np.float64(26.0)) , (175.0, 1.1) >
# < ('Itaque porro facere ipsa autem ipsa id aspernatur. Quia dolore quod asperiores odio. Magni temporibus expedita quas reprehenderit repellendus dolores.', np.float64(19.0)) , (270.0, 1.9) >
# < ('The interface could be better but overall good experience.', np.float64(47.0)) , (1235.0, 2.9) >
# < ('Latest update broke some features, please fix soon.', np.float64(51.0)) , (580.0, nan) >
# < ('Crashes too often, needs improvement in stability.', np.float64(67.0)) , (535.0, 3.6) >
# < ('Latest update broke some features, please fix soon.', np.float64(67.0)) , (282.0, 2.4) >
# < ('This app is amazing! Really love the new features.', np.float64(40.0)) , (1229.0, 4.3) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(25.0)) , (585.0, 4.7) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(71.0)) , (140.0, 1.8) >
# < ('Crashes too often, needs improvement in stability.', np.float64(45.0)) , (148.0, 3.0) >
# < ('Ipsam esse earum animi magni est iste. Fuga enim officia voluptate.', np.float64(43.0)) , (56.0, 3.7) >
# < ('The interface could be better but overall good experience.', np.float64(48.0)) , (155.0, 3.7) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(62.0)) , (319.0, 4.3) >
# < ('Tenetur nemo deleniti non magnam vero ipsum. Voluptatem assumenda officia aliquam provident voluptatibus.', np.float64(38.0)) , (573.0, 1.7) >
# < ('This app is amazing! Really love the new features.', np.float64(19.0)) , (1189.0, 3.7) >
# < ('Great app but too many ads, consider premium version.', np.float64(24.0)) , (923.0, 4.4) >
# < ('This app is amazing! Really love the new features.', np.float64(47.0)) , (1058.0, 2.7) >
# < ('工程使用就是这是经济大小地区一起. 任何设备还是为了.', np.float64(14.0)) , (704.0, 3.2) >
# < ('User-friendly design and smooth performance throughout.', np.float64(53.0)) , (949.0, 2.5) >
# < ('Latest update broke some features, please fix soon.', np.float64(62.0)) , (911.0, 3.6) >
# < ('The interface could be better but overall good experience.', np.float64(46.0)) , (813.0, 3.2) >
# < ('Great app but too many ads, consider premium version.', np.float64(72.0)) , (1107.0, 4.5) >
# < (nan, np.float64(22.0)) , (532.0, 2.2) >
# < ('Facere facere debitis distinctio veniam laborum dolorem.', np.float64(69.0)) , (843.0, 3.2) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(21.0)) , (373.0, 2.7) >
# < ('Crashes too often, needs improvement in stability.', np.float64(18.0)) , (476.0, 2.8) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(70.0)) , (393.0, 3.2) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(23.0)) , (661.0, 2.6) >
# < ('Crashes too often, needs improvement in stability.', np.float64(13.0)) , (497.0, 3.3) >
# < ('Crashes too often, needs improvement in stability.', np.float64(44.0)) , (257.0, 3.1) >
# < ('叔父細かい副彼尿軸。 ダイヤモンド普通の君はベルベット舗装ボトル部隊。 自体楽しんで動物チーズクルー君は高い。', np.float64(25.0)) , (1003.0, 3.2) >
# < ('Полевой мрачно потянуться понятный бригада. Монета монета мягкий рабочий песня табак отметить.', np.float64(59.0)) , (776.0, 1.0) >
# < ('Latest update broke some features, please fix soon.', np.float64(19.0)) , (226.0, 2.6) >
# < ('Excellent customer support and regular feature updates.', np.float64(58.0)) , (1240.0, 1.2) >
# < ('Hear history bank different five between research. Social case expert stop receive catch. Large accept bad eight strong nature road.', np.float64(17.0)) , (622.0, 3.1) >
# < ('User-friendly design and smooth performance throughout.', np.float64(63.0)) , (341.0, 3.7) >
# < ('Commodi dolores odit numquam aperiam. Nisi accusamus maiores doloribus corporis inventore nostrum. Necessitatibus deleniti pariatur minima facere.', np.float64(62.0)) , (768.0, 3.3) >
# < ('Minute Himmel können Opa Zug fliegen also. Gott Seite oft Spiel.', np.float64(45.0)) , (1133.0, 4.1) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(24.0)) , (988.0, 1.3) >
# < ('Excepturi odit rerum placeat voluptatem laboriosam delectus. Aperiam quod itaque eos.', np.float64(72.0)) , (1233.0, 4.5) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(21.0)) , (303.0, 2.2) >
# < ('Excellent customer support and regular feature updates.', np.float64(28.0)) , (504.0, 3.2) >
# < ('Latest update broke some features, please fix soon.', np.float64(52.0)) , (905.0, 5.0) >
# < ('The interface could be better but overall good experience.', np.float64(26.0)) , (679.0, 2.8) >
# < ('This app is amazing! Really love the new features.', np.float64(16.0)) , (555.0, 1.8) >
# < ('Commodi facilis suscipit quia tempora. Excepturi deleniti porro facilis reiciendis eaque.', np.float64(24.0)) , (180.0, 4.5) >
# < ('Great app but too many ads, consider premium version.', np.float64(30.0)) , (1026.0, 3.5) >
# < ('Скрытый развитый сравнение поймать художественный пересечь сомнительный. Расстегнуть опасность роскошный пища равнодушный необычный. Собеседник металл аж смелый.', np.float64(28.0)) , (854.0, 4.5) >
# < ('Sed perspiciatis ipsa commodi.', np.float64(17.0)) , (650.0, 4.7) >
# < ('Fugit necessitatibus non perspiciatis veniam fuga.', np.float64(51.0)) , (546.0, 1.1) >
# < ('追放するコピー指名ヘア。 バーゲン発生する運特徴。', np.float64(39.0)) , (66.0, 1.7) >
# < ('Dolor nostrum possimus voluptatum dicta consequatur asperiores. Tempore ipsum assumenda placeat.', np.float64(38.0)) , (640.0, 3.4) >
# < ('This app is amazing! Really love the new features.', np.float64(31.0)) , (388.0, 2.5) >
# < ('Enim error culpa quae praesentium cupiditate facere.', np.float64(38.0)) , (277.0, 4.8) >
# < ('User-friendly design and smooth performance throughout.', np.float64(59.0)) , (786.0, 2.5) >
# < ('User-friendly design and smooth performance throughout.', np.float64(74.0)) , (269.0, 3.5) >
# < ('The interface could be better but overall good experience.', np.float64(30.0)) , (1120.0, 3.4) >
# < ('Level work candidate this assume huge.', np.float64(52.0)) , (582.0, 5.0) >
# < ('Illum illum nemo commodi et asperiores iure. Exercitationem soluta quos odit delectus vitae inventore.', np.float64(20.0)) , (275.0, 1.3) >
# < ('Great app but too many ads, consider premium version.', np.float64(72.0)) , (724.0, 3.1) >
# < ('The interface could be better but overall good experience.', np.float64(39.0)) , (849.0, 4.4) >
# < ('Exercitationem velit tempora sapiente dolorum. Earum numquam nostrum atque odit nihil neque. Omnis quam non sapiente.', np.float64(66.0)) , (59.0, 2.4) >
# < ('Aliquid odit nemo officiis. Impedit odit libero occaecati enim vero laboriosam. Error asperiores animi ipsam laborum dignissimos.', np.float64(59.0)) , (1157.0, 4.3) >
# < ('Crashes too often, needs improvement in stability.', np.float64(20.0)) , (1218.0, 3.4) >
# < ('Voluptate consectetur fuga natus eum iure.', np.float64(70.0)) , (988.0, 2.8) >
# < ('スキーム教会チーズ血まみれの。 私リンク学生あった改善。', np.float64(32.0)) , (8.0, 4.5) >
# < ('Latest update broke some features, please fix soon.', np.float64(30.0)) , (240.0, 3.1) >
# < ('The interface could be better but overall good experience.', np.float64(41.0)) , (1107.0, 3.5) >
# < ('Great app but too many ads, consider premium version.', np.float64(75.0)) , (160.0, 3.9) >
# < ('Great app but too many ads, consider premium version.', np.float64(43.0)) , (133.0, 2.8) >
# < ('Сынок факультет ягода миллиард провал. Монета экзамен более неожиданно самостоятельно вскакивать покидать.', np.float64(48.0)) , (499.0, 3.4) >
# < ('Natus facere enim harum ipsum mollitia repudiandae. Perspiciatis blanditiis voluptate hic recusandae excepturi vel quidem. Nobis illo aliquam aliquam quae.', np.float64(65.0)) , (199.0, 2.9) >
# < ('Corrupti tempora consequuntur ut et hic nulla. Nisi magni magni laudantium natus. Repellendus fuga perferendis voluptatem nesciunt reiciendis quas.', np.float64(47.0)) , (927.0, 4.0) >
# < (nan, np.float64(36.0)) , (127.0, 4.4) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(21.0)) , (972.0, 1.8) >
# < ('パイオニア差別するタワークルー改善虐待トーン。 リニア今日ささやき錯覚呼ぶ。 協力柔らかい不自然な尿。', np.float64(21.0)) , (173.0, 4.9) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(58.0)) , (484.0, 1.0) >
# < ('Тесно равнодушный выкинуть бегать спорт. Нажать жидкий ученый свежий вообще интернет протягивать.', np.float64(18.0)) , (1249.0, 3.1) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(35.0)) , (862.0, 3.3) >
# < ('Latest update broke some features, please fix soon.', np.float64(18.0)) , (992.0, 3.5) >
# < ('Provident porro laborum laboriosam natus. Enim nemo molestiae tempore hic.', np.float64(44.0)) , (483.0, 4.2) >
# < ('Crashes too often, needs improvement in stability.', np.float64(54.0)) , (111.0, 3.3) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(56.0)) , (782.0, 2.2) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(62.0)) , (1205.0, 4.1) >
# < ('Latest update broke some features, please fix soon.', np.float64(16.0)) , (188.0, 1.8) >
# < ('User-friendly design and smooth performance throughout.', np.float64(62.0)) , (566.0, 4.7) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(22.0)) , (222.0, 2.6) >
# < ('Brusquement que dent arrêter. Debout dehors bois épaule interroger point chaleur. Vin ciel penser souhaiter jamais pendre rapporter.', np.float64(30.0)) , (799.0, 1.0) >
# < ('User-friendly design and smooth performance throughout.', np.float64(56.0)) , (682.0, 3.3) >
# < ('This app is amazing! Really love the new features.', np.float64(70.0)) , (798.0, 3.6) >
# < ('User-friendly design and smooth performance throughout.', np.float64(63.0)) , (691.0, 1.1) >
# < (nan, np.float64(28.0)) , (93.0, 2.9) >
# < ('Excellent customer support and regular feature updates.', np.float64(34.0)) , (872.0, 1.3) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(41.0)) , (337.0, 3.8) >
# < ('Ex quasi officia quaerat. Qui ratione necessitatibus.', np.float64(26.0)) , (259.0, 3.8) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(52.0)) , (195.0, 1.8) >
# < ('This app is amazing! Really love the new features.', np.float64(40.0)) , (429.0, 3.6) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(39.0)) , (667.0, 2.8) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(24.0)) , (931.0, 1.9) >
# < ('User-friendly design and smooth performance throughout.', np.float64(69.0)) , (450.0, 2.7) >
# < ('User-friendly design and smooth performance throughout.', np.float64(28.0)) , (505.0, 1.1) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(44.0)) , (926.0, nan) >
# < ('User-friendly design and smooth performance throughout.', np.float64(42.0)) , (931.0, 4.0) >
# < ('Latest update broke some features, please fix soon.', np.float64(63.0)) , (1178.0, 4.8) >
# < ('Great app but too many ads, consider premium version.', np.float64(58.0)) , (1148.0, 3.6) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(41.0)) , (707.0, 1.2) >
# < ('数字トリビュート本質的なスマッシュ不自然な。', np.float64(74.0)) , (590.0, 2.6) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(25.0)) , (597.0, 4.0) >
# < ('Latest update broke some features, please fix soon.', np.float64(63.0)) , (351.0, 1.5) >
# < ('Crashes too often, needs improvement in stability.', np.float64(28.0)) , (330.0, 3.8) >
# < ('Слишком носок угроза сутки. Бетонный смелый неправда умолять разнообразный парень присесть.', np.float64(62.0)) , (1022.0, 4.7) >
# < ('Autore notare assicurare nazione meglio né. Colpo soltanto invece prendere.', np.float64(21.0)) , (82.0, 3.8) >
# < ('Tempore ipsum animi consequatur. Itaque animi iure rem quam id.', np.float64(56.0)) , (912.0, 1.1) >
# < ('This app is amazing! Really love the new features.', np.float64(68.0)) , (912.0, 2.4) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(17.0)) , (686.0, 2.9) >
# < ('Latest update broke some features, please fix soon.', np.float64(27.0)) , (949.0, 2.2) >
# < ('Latest update broke some features, please fix soon.', np.float64(60.0)) , (1226.0, 5.0) >
# < ('Crashes too often, needs improvement in stability.', np.float64(23.0)) , (731.0, 2.8) >
# < ('Crashes too often, needs improvement in stability.', np.float64(30.0)) , (616.0, 2.3) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(67.0)) , (1076.0, 4.2) >
# < ('Fugiat placeat optio molestiae officiis expedita. Voluptatibus hic consectetur voluptatem. Quidem voluptatem iure.', np.float64(60.0)) , (58.0, 1.7) >
# < ('Here discover leave choice country themselves she.', np.float64(16.0)) , (1214.0, 1.1) >
# < ('Latest update broke some features, please fix soon.', np.float64(62.0)) , (1025.0, 2.4) >
# < ('Dignissimos aut alias nisi praesentium.', np.float64(57.0)) , (750.0, 4.4) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(48.0)) , (590.0, 3.0) >
# < ('Grecki zapalenie stan grudzień księga pozostać Egipt. Zgodnie handlowy zakon męski włosy gospodarczy.', np.float64(56.0)) , (1006.0, 2.5) >
# < ('Excellent customer support and regular feature updates.', np.float64(30.0)) , (1022.0, 1.5) >
# < ('Latest update broke some features, please fix soon.', np.float64(19.0)) , (60.0, 3.0) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(55.0)) , (601.0, 4.2) >
# < ('助けて彼今近代化するハンマー供給協力。 憲法発生するカレッジ普通の。', np.float64(69.0)) , (620.0, 1.1) >
# < ('Crashes too often, needs improvement in stability.', np.float64(50.0)) , (1013.0, 1.2) >
# < ('Great app but too many ads, consider premium version.', np.float64(28.0)) , (500.0, 2.6) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(14.0)) , (1204.0, 1.1) >
# < ('Great app but too many ads, consider premium version.', np.float64(26.0)) , (1097.0, 1.8) >
# < ('再現する電池ピックニュース月。 差別するトーンブラケット仕上げ必要。', np.float64(45.0)) , (618.0, 2.4) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(72.0)) , (548.0, 4.8) >
# < ('Latest update broke some features, please fix soon.', np.float64(67.0)) , (416.0, 2.6) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(23.0)) , (413.0, 3.6) >
# < ('The interface could be better but overall good experience.', np.float64(73.0)) , (812.0, 4.6) >
# < ('Great app but too many ads, consider premium version.', np.float64(72.0)) , (483.0, 4.3) >
# < ('User-friendly design and smooth performance throughout.', np.float64(36.0)) , (296.0, 2.0) >
# < ('Possimus provident id dolores eum.', np.float64(13.0)) , (795.0, 4.5) >
# < ('The interface could be better but overall good experience.', np.float64(58.0)) , (681.0, 2.9) >
# < ('Crashes too often, needs improvement in stability.', np.float64(49.0)) , (642.0, 2.6) >
# < ('Excellent customer support and regular feature updates.', np.float64(39.0)) , (172.0, 4.2) >
# < ('Suchen See Sommer Geschichte. Heiß ihn Musik Fahrrad denn.', np.float64(52.0)) , (821.0, 4.4) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(60.0)) , (589.0, 4.8) >
# < ('Dick gibt Herr Uhr leicht. Fragen traurig zehn Pferd leben drehen. Drehen sechs laut wenig mehr Pferd.', np.float64(56.0)) , (1193.0, 4.6) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(71.0)) , (964.0, 1.2) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(45.0)) , (347.0, 3.3) >
# < ('出来设计各种中国. 开发问题作为那些汽车重要公司.', np.float64(33.0)) , (1058.0, 4.3) >
# < ('User-friendly design and smooth performance throughout.', np.float64(20.0)) , (893.0, 1.7) >
# < ('Morte effetto mattino processo insistere. Breve bellezza chiudere contadino. Direttore fra salvare autorità uso leggere difficile.', np.float64(50.0)) , (434.0, 3.3) >
# < ('The interface could be better but overall good experience.', np.float64(66.0)) , (942.0, 1.6) >
# < ('电影等级方法作为. 技术谢谢工程人员.', np.float64(37.0)) , (1233.0, 4.0) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(21.0)) , (1235.0, 4.2) >
# < ('The interface could be better but overall good experience.', np.float64(54.0)) , (459.0, 3.1) >
# < ('Latest update broke some features, please fix soon.', np.float64(45.0)) , (92.0, 1.2) >
# < ('Crashes too often, needs improvement in stability.', np.float64(33.0)) , (609.0, 1.2) >
# < ('Natus adipisci ut et vero nesciunt quibusdam. Ut error natus necessitatibus sed perspiciatis.', np.float64(13.0)) , (238.0, 1.1) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(26.0)) , (54.0, 4.3) >
# < ('Crashes too often, needs improvement in stability.', np.float64(14.0)) , (965.0, 3.8) >
# < ('法律都是网络设计如果提高或者.', np.float64(59.0)) , (1210.0, 2.6) >
# < ('Odio quos iste. Explicabo velit inventore perspiciatis optio.', np.float64(59.0)) , (589.0, 2.7) >
# < ('Quae aspernatur culpa quae odio. Et autem a est facere earum. Assumenda inventore nam maiores.', np.float64(52.0)) , (331.0, 2.4) >
# < ('This app is amazing! Really love the new features.', np.float64(56.0)) , (731.0, 2.4) >
# < ('Nisi eveniet harum eos harum assumenda temporibus temporibus. Nemo cumque fugit consequuntur error.', np.float64(70.0)) , (547.0, 4.1) >
# < ('The interface could be better but overall good experience.', np.float64(23.0)) , (740.0, 3.5) >
# < ('Error quos facere velit quam libero.', np.float64(31.0)) , (699.0, 4.3) >
# < ('索引隠すコピー符号。 サワー再現する合計学生装置彼女。 憲法ブラケットデッドタワー。', np.float64(22.0)) , (906.0, 2.4) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(59.0)) , (623.0, nan) >
# < ('Quos eveniet eligendi ratione facilis ut dicta. Debitis quisquam ad quas velit distinctio reiciendis. Reprehenderit recusandae illum libero.', np.float64(15.0)) , (172.0, 4.1) >
# < ('Perte prier résistance autrement voix.', np.float64(29.0)) , (1213.0, 4.6) >
# < ('This app is amazing! Really love the new features.', np.float64(49.0)) , (1191.0, 2.4) >
# < ('Excellent customer support and regular feature updates.', np.float64(19.0)) , (930.0, 4.3) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(57.0)) , (901.0, 3.3) >
# < ('Встать разводить ученый изменение. Аллея банда изменение.', np.float64(20.0)) , (225.0, 3.4) >
# < ('Latest update broke some features, please fix soon.', np.float64(20.0)) , (4.0, 1.9) >
# < ('User-friendly design and smooth performance throughout.', np.float64(64.0)) , (182.0, 2.8) >
# < ('Latest update broke some features, please fix soon.', np.float64(25.0)) , (174.0, 3.6) >
# < ('Schlagen Fahrrad helfen kommen schenken schlimm dich über. Bruder ihr Wort dafür wir den genau. Stadt los grün braun See Kind Bein.', np.float64(33.0)) , (1242.0, 2.8) >
# < ('Latest update broke some features, please fix soon.', np.float64(32.0)) , (315.0, 1.7) >
# < ('Ut qui maiores mollitia.', np.float64(28.0)) , (1200.0, 2.0) >
# < ('Excellent customer support and regular feature updates.', np.float64(32.0)) , (257.0, 1.4) >
# < ('This app is amazing! Really love the new features.', np.float64(54.0)) , (592.0, 4.8) >
# < ('Hic qui sunt ipsum inventore a.', np.float64(59.0)) , (286.0, 1.4) >
# < ('User-friendly design and smooth performance throughout.', np.float64(51.0)) , (4.0, 2.3) >
# < ('Great app but too many ads, consider premium version.', np.float64(24.0)) , (792.0, 4.3) >
# < ('User-friendly design and smooth performance throughout.', np.float64(26.0)) , (1241.0, 1.1) >
# < ('Excellent customer support and regular feature updates.', np.float64(72.0)) , (531.0, 4.0) >
# < ('This app is amazing! Really love the new features.', np.float64(20.0)) , (561.0, 2.7) >
# < ('The interface could be better but overall good experience.', np.float64(74.0)) , (867.0, 4.2) >
# < ('Great app but too many ads, consider premium version.', np.float64(73.0)) , (484.0, 4.3) >
# < ('User-friendly design and smooth performance throughout.', np.float64(19.0)) , (134.0, 2.2) >
# < ('Great app but too many ads, consider premium version.', np.float64(46.0)) , (929.0, 4.8) >
# < ('Excellent customer support and regular feature updates.', np.float64(16.0)) , (90.0, 1.7) >
# < ('This app is amazing! Really love the new features.', np.float64(28.0)) , (117.0, 3.3) >
# < ('Excellent customer support and regular feature updates.', np.float64(39.0)) , (613.0, 4.9) >
# < (nan, np.float64(65.0)) , (377.0, 2.5) >
# < ('Latest update broke some features, please fix soon.', np.float64(24.0)) , (503.0, 1.7) >
# < ('Great app but too many ads, consider premium version.', np.float64(69.0)) , (888.0, 1.7) >
# < ('In consequuntur fugit delectus odio possimus.', np.float64(28.0)) , (671.0, 2.2) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(33.0)) , (366.0, 3.0) >
# < ('Latest update broke some features, please fix soon.', np.float64(72.0)) , (321.0, 4.6) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(30.0)) , (649.0, 2.5) >
# < ('Great app but too many ads, consider premium version.', np.float64(56.0)) , (402.0, 3.2) >
# < ('Consequatur repellendus vitae magnam libero placeat impedit. Laborum assumenda adipisci quis eos eius.', np.float64(54.0)) , (966.0, 4.3) >
# < ('Natus quo libero magni nemo eaque molestiae.', np.float64(41.0)) , (429.0, 4.1) >
# < ('Nave volere bisognare serio restare errore. Lago forma segnare. Sotto camminare scusare coscienza raggiungere prezzo.', np.float64(63.0)) , (1162.0, 2.3) >
# < ('User-friendly design and smooth performance throughout.', np.float64(18.0)) , (623.0, 2.3) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(13.0)) , (1061.0, 2.8) >
# < ('User-friendly design and smooth performance throughout.', np.float64(25.0)) , (1203.0, nan) >
# < ('The interface could be better but overall good experience.', np.float64(57.0)) , (710.0, 3.6) >
# < ('This app is amazing! Really love the new features.', np.float64(69.0)) , (560.0, 4.5) >
# < ('Посвятить скрытый лететь казнь задержать беспомощный. Вперед дыхание обида забирать.', np.float64(45.0)) , (424.0, 2.8) >
# < ('Désormais prétendre santé recommencer. Jusque musique distinguer garde humide parti.', np.float64(17.0)) , (944.0, 4.0) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(56.0)) , (22.0, 2.6) >
# < ('User-friendly design and smooth performance throughout.', np.float64(62.0)) , (772.0, 3.4) >
# < ('Force able similar run room learn professional. Sure somebody huge why station manager.', np.float64(48.0)) , (660.0, 1.4) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(15.0)) , (755.0, 1.9) >
# < ('Crashes too often, needs improvement in stability.', np.float64(17.0)) , (987.0, 1.7) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(36.0)) , (281.0, 3.5) >
# < ('Aut quos itaque. Ut culpa itaque voluptatibus. Dicta porro consequatur officiis culpa ut.', np.float64(34.0)) , (678.0, 4.0) >
# < ('User-friendly design and smooth performance throughout.', np.float64(73.0)) , (289.0, 4.8) >
# < ('Crashes too often, needs improvement in stability.', np.float64(41.0)) , (1180.0, 2.0) >
# < ('Zaczynać tkanina mi. Hiszpański szkoła wieś pracownik pochodzić.', np.float64(61.0)) , (170.0, 4.0) >
# < ('User-friendly design and smooth performance throughout.', np.float64(13.0)) , (8.0, 1.6) >
# < ('Possimus repellendus voluptates. Possimus labore dolorem at rem aut.', np.float64(62.0)) , (522.0, 1.6) >
# < ('Crashes too often, needs improvement in stability.', np.float64(28.0)) , (520.0, 3.4) >
# < ('Aussitôt moindre on coin. Profiter parent cheveu fumer port simple.', np.float64(55.0)) , (1091.0, 3.8) >
# < ('This app is amazing! Really love the new features.', np.float64(17.0)) , (198.0, 4.3) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(29.0)) , (392.0, 1.8) >
# < ('User-friendly design and smooth performance throughout.', np.float64(30.0)) , (125.0, 4.0) >
# < ('Great app but too many ads, consider premium version.', np.float64(73.0)) , (490.0, 4.6) >
# < (nan, np.float64(45.0)) , (973.0, 2.5) >
# < ('Excellent customer support and regular feature updates.', np.float64(59.0)) , (205.0, 2.4) >
# < ('細かい目的品質午前風景陶器。', np.float64(28.0)) , (1107.0, 4.8) >
# < ('Aliquam aperiam ratione magni occaecati. Quisquam incidunt illo odit modi corrupti assumenda.', np.float64(53.0)) , (1094.0, 1.5) >
# < ('Modi hic odio rerum.', np.float64(20.0)) , (179.0, 2.0) >
# ...
# < ('Works perfectly on my device, no complaints at all.', np.float64(26.0)) , (936.0, 4.7) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(30.0)) , (470.0, 4.1) >
# < ('Pericoloso bravo lontano dunque no industriale. Baciare stabilire porre loro.', np.float64(64.0)) , (998.0, 1.5) >
# < ('User-friendly design and smooth performance throughout.', np.float64(45.0)) , (500.0, 2.6) >
# < ('Necessitatibus optio ipsum voluptatum. Nam labore voluptas omnis neque blanditiis.', np.float64(57.0)) , (693.0, 3.0) >
# < ('Error quia hic fuga.', np.float64(63.0)) , (376.0, 4.1) >
# < ('Latest update broke some features, please fix soon.', np.float64(40.0)) , (697.0, 2.7) >
# < ('Minus esse repellat eum doloribus laboriosam distinctio optio.', np.float64(31.0)) , (522.0, 4.5) >
# < ('Crashes too often, needs improvement in stability.', np.float64(40.0)) , (1139.0, 4.3) >
# < ('Odio molestiae rem corporis consectetur magni similique. Labore voluptatibus asperiores cum.', np.float64(48.0)) , (834.0, 1.3) >
# < ('User-friendly design and smooth performance throughout.', np.float64(62.0)) , (852.0, 4.3) >
# < ('Материя жить применяться опасность карман.', np.float64(41.0)) , (392.0, 1.3) >
# < ('Great app but too many ads, consider premium version.', np.float64(20.0)) , (318.0, 3.0) >
# < ('Crashes too often, needs improvement in stability.', np.float64(65.0)) , (1040.0, 2.2) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(71.0)) , (947.0, 3.5) >
# < ('Veniam magni illo sit odio dolores maxime libero. Inventore adipisci architecto assumenda.', np.float64(69.0)) , (135.0, 2.4) >
# < ('Fuga hic iure.', np.float64(46.0)) , (430.0, 5.0) >
# < ('ブラケットはカラム建築省略サラダ符号。 デッド持つブラケットヒール埋め込む建築野球省略。', np.float64(31.0)) , (600.0, 1.1) >
# < ('Great app but too many ads, consider premium version.', np.float64(48.0)) , (787.0, 2.6) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(42.0)) , (1052.0, 1.2) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(52.0)) , (921.0, 4.6) >
# < ('电脑日期一起一起起来点击会员其实. 影响美国销售合作世界或者责任. 世界表示数据感觉通过.', np.float64(52.0)) , (1242.0, 2.3) >
# < ('Blanditiis quam eos doloribus. Ratione rerum delectus officia libero doloribus laborum earum.', np.float64(54.0)) , (150.0, 4.9) >
# < ('Chiesa pagina direttore vendere secolo vita.', np.float64(26.0)) , (981.0, 4.5) >
# < ('Crashes too often, needs improvement in stability.', np.float64(26.0)) , (610.0, 3.8) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(68.0)) , (1233.0, 5.0) >
# < ('Maiores in eaque voluptatem occaecati. Nisi labore harum blanditiis debitis facere reiciendis.', np.float64(29.0)) , (596.0, 1.2) >
# < ('User-friendly design and smooth performance throughout.', np.float64(70.0)) , (567.0, 1.7) >
# < ('Environmental six understand rather daughter through note.', np.float64(57.0)) , (1247.0, 2.7) >
# < ('Excellent customer support and regular feature updates.', np.float64(74.0)) , (806.0, 1.7) >
# < ('Crashes too often, needs improvement in stability.', np.float64(39.0)) , (1080.0, 2.6) >
# < ('Excellent customer support and regular feature updates.', np.float64(29.0)) , (1249.0, 2.7) >
# < ('Latest update broke some features, please fix soon.', np.float64(23.0)) , (778.0, 1.5) >
# < ('This app is amazing! Really love the new features.', np.float64(14.0)) , (658.0, 2.0) >
# < ('Latest update broke some features, please fix soon.', np.float64(53.0)) , (641.0, 4.8) >
# < ('Sommer dumm Zahl heute mehr also.', np.float64(70.0)) , (636.0, 2.7) >
# < ('注意不过单位网络谢谢地址还有联系.', np.float64(17.0)) , (628.0, 1.9) >
# < ('This app is amazing! Really love the new features.', np.float64(60.0)) , (574.0, 4.0) >
# < ('Great app but too many ads, consider premium version.', np.float64(34.0)) , (368.0, 2.4) >
# < ('User-friendly design and smooth performance throughout.', np.float64(62.0)) , (526.0, 4.4) >
# < ('Distinctio aut aspernatur quae ipsam qui fugit. Quibusdam ad quisquam dignissimos perferendis ipsa soluta exercitationem. Libero nulla saepe.', np.float64(52.0)) , (822.0, 1.3) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(63.0)) , (1220.0, 2.5) >
# < ('This app is amazing! Really love the new features.', np.float64(69.0)) , (30.0, 3.2) >
# < ('Great app but too many ads, consider premium version.', np.float64(73.0)) , (709.0, 2.5) >
# < ('Latest update broke some features, please fix soon.', np.float64(18.0)) , (719.0, 1.3) >
# < ('Kawałek koza diabeł zupełnie bawić się białoruski. Źródło kolano szczególnie ukraiński Azja długość połączenie. 10 ponownie niedziela sportowy przedstawiciel bliski kij.', np.float64(13.0)) , (406.0, 3.4) >
# < ("Danger neuf l'une manier. Sentiment violence façon réclamer beau. Besoin pourtant arracher avenir.", np.float64(13.0)) , (957.0, 3.7) >
# < ('Great app but too many ads, consider premium version.', np.float64(38.0)) , (516.0, 4.6) >
# < ('Crashes too often, needs improvement in stability.', np.float64(13.0)) , (550.0, 3.5) >
# < ('Crashes too often, needs improvement in stability.', np.float64(52.0)) , (808.0, 3.7) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(36.0)) , (860.0, 1.7) >
# < ('Great app but too many ads, consider premium version.', np.float64(66.0)) , (121.0, 5.0) >
# < ('Ob müde Stadt von.', np.float64(67.0)) , (267.0, 3.0) >
# < ('Помимо ход дрогнуть коробка демократия. Подробность возмутиться сопровождаться картинка ложиться. Приличный заработать умолять рис тяжелый изредка прелесть.', np.float64(47.0)) , (250.0, 1.7) >
# < ('Great app but too many ads, consider premium version.', np.float64(47.0)) , (677.0, 2.1) >
# < ('更新类型电子. 这个支持有限决定.', np.float64(61.0)) , (1194.0, 4.9) >
# < ('Great app but too many ads, consider premium version.', np.float64(29.0)) , (50.0, 1.8) >
# < ('Iste quae quae cum non. Architecto fugiat a. Minus laudantium quidem mollitia quas suscipit iure.', np.float64(26.0)) , (869.0, 4.2) >
# < ('Crashes too often, needs improvement in stability.', np.float64(47.0)) , (59.0, 4.8) >
# < ('Latest update broke some features, please fix soon.', np.float64(38.0)) , (123.0, 3.8) >
# < ('Minima illum magnam libero rem.', np.float64(72.0)) , (311.0, 1.5) >
# < ('Latest update broke some features, please fix soon.', np.float64(68.0)) , (716.0, 2.2) >
# < ('Excellent customer support and regular feature updates.', np.float64(56.0)) , (452.0, 3.8) >
# < ('Error ad laborum quibusdam dolor quod. Ipsum nihil quis consequuntur. Id consequuntur tempore temporibus ducimus.', np.float64(35.0)) , (157.0, 4.9) >
# < ('Excellent customer support and regular feature updates.', np.float64(53.0)) , (740.0, 1.3) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(59.0)) , (657.0, 4.1) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(28.0)) , (834.0, 4.3) >
# < (nan, np.float64(60.0)) , (1005.0, 1.4) >
# < ('Excellent customer support and regular feature updates.', np.float64(67.0)) , (1195.0, 4.8) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(46.0)) , (691.0, 1.4) >
# < ('User-friendly design and smooth performance throughout.', np.float64(32.0)) , (264.0, 2.4) >
# < ('Crashes too often, needs improvement in stability.', np.float64(54.0)) , (533.0, 3.2) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(20.0)) , (610.0, 3.1) >
# < ('Crashes too often, needs improvement in stability.', np.float64(47.0)) , (1108.0, 2.4) >
# < ('Ad illo reiciendis itaque numquam eligendi.', np.float64(54.0)) , (66.0, 4.1) >
# < ('Latest update broke some features, please fix soon.', np.float64(21.0)) , (202.0, 4.9) >
# < ('User-friendly design and smooth performance throughout.', np.float64(13.0)) , (516.0, 2.1) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(22.0)) , (67.0, 3.2) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(13.0)) , (89.0, 2.7) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(68.0)) , (813.0, 3.2) >
# < ('Ex quae quasi odio corporis quis. At fugit hic aliquam esse. Deserunt necessitatibus in repudiandae.', np.float64(68.0)) , (419.0, 1.7) >
# < ('Ducimus totam a architecto similique eaque laboriosam.', np.float64(66.0)) , (341.0, 3.9) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(35.0)) , (663.0, 3.6) >
# < ('Latest update broke some features, please fix soon.', np.float64(19.0)) , (1247.0, 3.6) >
# < ('Excellent customer support and regular feature updates.', np.float64(32.0)) , (1248.0, 3.7) >
# < ('Veritatis ducimus nam suscipit repellendus ex pariatur.', np.float64(53.0)) , (969.0, 4.8) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(75.0)) , (45.0, 2.4) >
# < ('Crashes too often, needs improvement in stability.', np.float64(35.0)) , (676.0, 4.6) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(31.0)) , (383.0, 4.4) >
# < ('Evening vote feel win yard anything option. Blood challenge difference situation thing. Less check better my guy.', np.float64(70.0)) , (992.0, 4.2) >
# < ('Excellent customer support and regular feature updates.', np.float64(58.0)) , (75.0, 4.4) >
# < ('Great app but too many ads, consider premium version.', np.float64(28.0)) , (935.0, 2.9) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(36.0)) , (1107.0, 3.2) >
# < ('This app is amazing! Really love the new features.', np.float64(54.0)) , (829.0, 2.4) >
# < ('Idea intanto importare vicino figura genere. Destino staccare mandare uscire operazione. Insieme desiderio difficile scomparire film oro.', np.float64(26.0)) , (789.0, 2.5) >
# < ('Aspernatur recusandae ab molestiae. Tempore vel recusandae possimus corrupti amet iusto. Consequatur voluptates facilis.', np.float64(23.0)) , (572.0, 2.4) >
# < ('This app is amazing! Really love the new features.', np.float64(57.0)) , (904.0, 3.9) >
# < ('Dort Geld Brief. Bild auch ab werden steigen Wasser treffen leben. Nehmen nächste lustig Tür fünf.', np.float64(29.0)) , (963.0, 3.3) >
# < ('The interface could be better but overall good experience.', np.float64(37.0)) , (940.0, 4.7) >
# < ('Libero dolore eligendi hic.', np.float64(39.0)) , (274.0, 1.8) >
# < ('連続オークション出演者コミュニケーションデフォルト状況サワー。 トレーナーバナー敵対的なリフト楽しんで。', np.float64(53.0)) , (192.0, 2.3) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(58.0)) , (1193.0, 5.0) >
# < ('Corporis voluptatum commodi quam. Quo porro neque quaerat ipsa. Ut pariatur perferendis quas.', np.float64(19.0)) , (681.0, 2.1) >
# < ('The interface could be better but overall good experience.', np.float64(37.0)) , (992.0, 4.8) >
# < ('Culpa deleniti architecto adipisci sequi dolorum.', np.float64(64.0)) , (77.0, 4.2) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(36.0)) , (1097.0, 1.2) >
# < (nan, np.float64(27.0)) , (237.0, 4.1) >
# < ('Great app but too many ads, consider premium version.', np.float64(34.0)) , (448.0, 3.2) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(58.0)) , (707.0, 3.2) >
# < (nan, np.float64(19.0)) , (53.0, 4.5) >
# < ('大統領普通のブラケット。 舗装改善管理する虐待アクセルペダル。 リハビリ癌コミュニティホイール賞賛する不自然な。', np.float64(23.0)) , (413.0, 3.9) >
# < ('Früh hin mal neben Wetter Ende Spaß. Klasse Schüler merken.', np.float64(67.0)) , (186.0, 2.4) >
# < ('Crashes too often, needs improvement in stability.', np.float64(21.0)) , (610.0, 2.2) >
# < ('Excellent customer support and regular feature updates.', np.float64(55.0)) , (542.0, 3.2) >
# < ('User-friendly design and smooth performance throughout.', np.float64(30.0)) , (1063.0, 1.7) >
# < ('Latest update broke some features, please fix soon.', np.float64(15.0)) , (952.0, 3.2) >
# < ('User-friendly design and smooth performance throughout.', np.float64(24.0)) , (879.0, 4.7) >
# < ("Toit se d'autres discours suffire.", np.float64(23.0)) , (327.0, 2.7) >
# < ('Ducimus eaque minus aliquam veritatis ipsum id inventore.', np.float64(71.0)) , (596.0, 3.7) >
# < ('Excellent customer support and regular feature updates.', np.float64(15.0)) , (713.0, 3.3) >
# < ('Mattino unico salutare.', np.float64(54.0)) , (1041.0, 3.9) >
# < ('Great app but too many ads, consider premium version.', np.float64(64.0)) , (707.0, 3.0) >
# < ('Подземный естественный освободить дьявол носок тесно грудь. Разводить приятель привлекать грудь прелесть выкинуть ленинград.', np.float64(59.0)) , (955.0, 3.7) >
# < ('Crashes too often, needs improvement in stability.', np.float64(34.0)) , (353.0, 4.4) >
# < ('The interface could be better but overall good experience.', np.float64(39.0)) , (912.0, 2.7) >
# < (nan, np.float64(75.0)) , (406.0, 4.4) >
# < ('Great app but too many ads, consider premium version.', np.float64(63.0)) , (389.0, 4.6) >
# < ("Réel eau vraiment poste. Avant chose cause tranquille. Aujourd'Hui rejeter rayon dix conclure.", np.float64(41.0)) , (576.0, 2.1) >
# < ('The interface could be better but overall good experience.', np.float64(19.0)) , (75.0, 1.2) >
# < ('Excellent customer support and regular feature updates.', np.float64(50.0)) , (524.0, 1.1) >
# < ('Perfect for daily use, highly recommend to everyone.', np.float64(16.0)) , (592.0, 3.9) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(37.0)) , (79.0, 2.8) >
# < ('Great app but too many ads, consider premium version.', np.float64(43.0)) , (937.0, 2.1) >
# < ('Great app but too many ads, consider premium version.', np.float64(38.0)) , (73.0, nan) >
# < ('The interface could be better but overall good experience.', np.float64(33.0)) , (297.0, 1.6) >
# < ('Excellent customer support and regular feature updates.', np.float64(39.0)) , (480.0, 2.3) >
# < ('Cum exercitationem minima porro. Laboriosam unde occaecati adipisci sequi. Aut maiores repellat distinctio deleniti odit.', np.float64(73.0)) , (925.0, 1.5) >
# < ('Impreza trzydziesty zwycięstwo delikatny należy. Samica historia nad kupować który ser.', np.float64(53.0)) , (542.0, 1.6) >
# < ('您的时间成为非常公司网络. 的话发表公司今天全部因此资料. 中文责任作为推荐投资回复工作我的.', np.float64(17.0)) , (684.0, 4.5) >
# < ('User-friendly design and smooth performance throughout.', np.float64(13.0)) , (1010.0, 3.0) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(18.0)) , (789.0, 3.7) >
# < ('Один указанный аж услать трясти жить. Один сравнение бригада.', np.float64(67.0)) , (179.0, 2.7) >
# < ('Nobis aut beatae voluptate quisquam et commodi nemo.', np.float64(54.0)) , (1219.0, 1.9) >
# < ('This app is amazing! Really love the new features.', np.float64(15.0)) , (446.0, 3.4) >
# < ('Latest update broke some features, please fix soon.', np.float64(39.0)) , (432.0, nan) >
# < ('Нажать достоинство мелочь понятный роскошный помимо тревога.', np.float64(26.0)) , (1098.0, 4.6) >
# < ('Great app but too many ads, consider premium version.', np.float64(25.0)) , (571.0, 4.9) >
# < ('Ullam in omnis eaque amet.', np.float64(40.0)) , (436.0, 4.8) >
# < ('Excellent customer support and regular feature updates.', np.float64(23.0)) , (214.0, 3.0) >
# < (nan, np.float64(51.0)) , (19.0, 4.6) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(30.0)) , (98.0, 2.2) >
# < ('This app is amazing! Really love the new features.', np.float64(59.0)) , (346.0, 2.1) >
# < ('Some bugs need fixing but generally satisfied with it.', np.float64(70.0)) , (1179.0, 4.2) >
# < ('Works perfectly on my device, no complaints at all.', np.float64(29.0)) , (621.0, 4.1) >
# < ('ノート暖かい学生建築職人ジャム花嫁。 普通のスマッシュ目的トースト埋め込むシュガー符号。 分割極端なリフト敵対的な怒り追放する知覚。', np.float64(46.0)) , (214.0, 2.8) >
# < ('功能一些工具因为全国解决以上注意. 然后这么包括女人根据那个.', np.float64(17.0)) , (649.0, 4.8) >
# < ('Счастье низкий пастух. Нож неожиданно поезд тревога. Монета крыса эпоха металл командование следовательно правый.', np.float64(21.0)) , (635.0, 3.0) >
# < ('This app is amazing! Really love the new features.', np.float64(38.0)) , (1127.0, 1.9) >
# < ('This app is amazing! Really love the new features.', np.float64(27.0)) , (677.0, 3.4) >
# < ('Invitare convincere pericoloso corsa fortuna. Mamma uguale internazionale direttore intendere.', np.float64(35.0)) , (155.0, 2.7) >
# < ('Latest update broke some features, please fix soon.', np.float64(26.0)) , (1040.0, 2.1) >

# %% [markdown]
# # Conclusion
#
# In short, properly organizing our data is a crucial first step for AI/ML. By labeling the dataset, counting the examples (m), and separating the inputs (x) from the outputs (y), we change messy data into a clear and concise form. This is the basic foundation required for all future work, like training a model. This method helps FinTech companies use their data to understand customer feedback and make better decisions.
